# %% [markdown]
# # Stop Sign Violations
# traffic violations are no joke since many lives can be lost to reckless and careless driving. One thing in particular is that of running stop signs. Stop signs are purposefully placed in areas where pedestrians and oncoming traffic might be difficult to spot prior to entering an intersection, therefore, it is important to actually make the stop. Some complaint and question the placement of the actual signs in certain areas which makes them difficult to spot, therefore we hereby propose an experiment to test the potential effect of placing warning signs prior to an stop sign on driving behavior.

# %% [markdown]
# data acquired from https://www.kaggle.com/rounak041993/traffic-violations-in-maryland-county

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats

# %%
df = pd.DataFrame(pd.read_csv("Traffic_Violations.csv"))

dates = df["Date Of Stop"]
year = []
month = []
for date in dates:
    mylist = date.split("/")
    year.append(int(mylist[2]))
    month.append(int(mylist[0]))
df["Year"] = year
df["Month"] = month

df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Date Of Stop Time Of Stop Agency  \
# 0   09/24/2013     17:11:00    MCP
# 1   08/29/2017     10:19:00    MCP
# 2   12/01/2014     12:52:00    MCP
# 3   08/29/2017     09:22:00    MCP
# 4   08/28/2017     23:41:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2  6th district, Gaithersburg / Montgomery Village
# 3                      3rd district, Silver Spring
# 4  6th district, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2                 FAILURE STOP AND YIELD AT THRU HWY
# 3               FAILURE YIELD RIGHT OF WAY ON U TURN
# 4  FAILURE OF DR. TO MAKE LANE CHANGE TO AVAIL. L...
#
#                                  Location   Latitude  Longitude Accident  \
# 0                         8804 FLOWER AVE        NaN        NaN       No
# 1                   WISCONSIN AVE@ ELM ST  38.981725 -77.092757       No
# 2  CHRISTOPHER AVE/MONTGOMERY VILLAGE AVE  39.162888 -77.229088       No
# 3         CHERRY HILL RD./CALVERTON BLVD.  39.056975 -76.954633       No
# 4              355 @ SOUTH WESTLAND DRIVE        NaN        NaN       No
#
#   Belts  ...                  Article Contributed To Accident   Race Gender  \
# 0    No  ...   Transportation Article                      No  BLACK      M
# 1    No  ...   Transportation Article                      No  WHITE      F
# 2    No  ...   Transportation Article                      No  BLACK      F
# 3    No  ...   Transportation Article                      No  BLACK      M
# 4    No  ...   Transportation Article                      No  WHITE      M
#
#        Driver City Driver State DL State        Arrest Type  \
# 0      TAKOMA PARK           MD       MD  A - Marked Patrol
# 1  FAIRFAX STATION           VA       VA  A - Marked Patrol
# 2   UPPER MARLBORO           MD       MD  A - Marked Patrol
# 3  FORT WASHINGTON           MD       MD  A - Marked Patrol
# 4     GAITHERSBURG           MD       MD  A - Marked Patrol
#
#                              Geolocation Month
# 0                                    NaN     9
# 1         (38.981725, -77.0927566666667)     8
# 2  (39.1628883333333, -77.2290883333333)    12
# 3         (39.056975, -76.9546333333333)     8
# 4                                    NaN     8
#
# [5 rows x 36 columns]

# %%
df1 = df[df["Description"].str.contains("STOP SIGN")==1]
len(df1)
# Out:
# 42995

# %%
# summary of daily stops
print(df1.groupby("Date Of Stop").size().describe())
# Out:
# count    2301.000000
# mean       18.685354
# std         9.841045
# min         1.000000
# 25%        12.000000
# 50%        17.000000
# 75%        24.000000
# max        72.000000
# dtype: float64

# %%
# process location
seps = ( " AT "," AND ", "@", "/")
ends = ( " RD", " BLVD", " AVE", " DRIVE", " DR",
         " ST", " PL", " LN", " PKWY", " LANE", " WAY", "WA" )

def seperate(s):
    for sep in seps:
        if sep in s:
            temp = s.split(sep)
            return[temp[0].strip(), temp[1].strip()]
    return [s, ""]

def trim_end(s):
    for end in ends:
        if end in s:
            return s.split(end)[0].strip()
    return s

locations = df1["Location"]
locs = []
for location in locations:
    temp = seperate(location)
    locs.append((trim_end(temp[0]),trim_end(temp[1])))
    
df1["clean_location"] = locs
df1.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Date Of Stop Time Of Stop Agency  \
# 14    07/20/2012     23:12:00    MCP
# 43    05/25/2012     10:39:00    MCP
# 126   08/04/2014     10:46:00    MCP
# 237   09/30/2014     10:49:00    MCP
# 462   08/29/2017     00:20:00    MCP
#
#                                            SubAgency  \
# 14                          5th district, Germantown
# 43                       3rd district, Silver Spring
# 126                      3rd district, Silver Spring
# 237                            4th district, Wheaton
# 462  6th district, Gaithersburg / Montgomery Village
#
#                                   Description  \
# 14               FAILURE TO STOP AT STOP SIGN
# 43   DRIVER FAILURE TO STOP AT STOP SIGN LINE
# 126              FAILURE TO STOP AT STOP SIGN
# 237              FAILURE TO STOP AT STOP SIGN
# 462  DRIVER FAILURE TO STOP AT STOP SIGN LINE
#
#                                Location   Latitude  Longitude Accident Belts  \
# 14      WISTERIA DR @ WARING STATION RD  39.161810 -77.253581       No    No
# 43    SB BROADBIRCH DR/ PLUM ORCHARD DR  39.055911 -76.957965       No    No
# 126  ASTON MANOR DR/GATESHEAD MANOR WAY  39.079053 -76.938700       No    No
# 237             BEL PRE RD / ARCTIC AVE  39.095217 -77.092055       No    No
# 462             WEST DEER PK @ DUVAL LN  39.127600 -77.196837       No    No
#
#                   ...               Contributed To Accident      Race Gender  \
# 14                ...                                    No     ASIAN      F
# 43                ...                                    No     WHITE      M
# 126               ...                                    No     BLACK      M
# 237               ...                                    No  HISPANIC      F
# 462               ...                                    No  HISPANIC      F
#
#        Driver City Driver State DL State        Arrest Type  \
# 14      GERMANTOWN           MD       MD  A - Marked Patrol
# 43        GLEN ARM           MD       MD  A - Marked Patrol
# 126  SILVER SPRING           MD       MD  A - Marked Patrol
# 237  SILVER SPRING           MD       MD  A - Marked Patrol
# 462   GAITHERSBURG           MD       MD  A - Marked Patrol
#
#                                Geolocation Month  \
# 14        (39.1618098166667, -77.25358095)     7
# 43   (39.0559105666667, -76.9579645166667)     5
# 126           (39.0790533333333, -76.9387)     8
# 237         (39.0952166666667, -77.092055)     9
# 462           (39.1276, -77.1968366666667)     8
#
#                      clean_location
# 14       (WISTERIA, WARING STATION)
# 43    (SB BROADBIRCH, PLUM ORCHARD)
# 126  (ASTON MANOR, GATESHEAD MANOR)
# 237               (BEL PRE, ARCTIC)
# 462           (WEST DEER PK, DUVAL)
#
# [5 rows x 37 columns]

# %%
# stops by time

# %%
import datetime as dt

times = df1["Time Of Stop"]
t = []
h = []

for time in times:
    values = time.split(":")
    t.append(dt.time(int(values[0]), int(values[1]), int(values[2])))
    h.append(int(values[0]))
    
df1["Time"] = t
df1["Hour"] = h
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
print(df1.groupby("Hour").size().describe())
sns.countplot(df1["Hour"], color = "grey")
# Out:
# count      24.000000
# mean     1791.458333
# std       900.811614
# min       259.000000
# 25%      1280.500000
# 50%      1835.000000
# 75%      2386.500000
# max      3553.000000
# dtype: float64

# %%
# stops by location

# %%
print(df1.groupby("clean_location").size().sort_values(ascending=False).head(74))
len(df1.groupby("clean_location"))

#  " AT " " AND " " @ " "/" ""
#  " RD" " BLVD" " AVE" " DRIVE" " DR" " ST" " PL" " LN" " PKWY"
# Out:
# clean_location
# (PLYERS MILL, LEXINGTON)             885
# (BROADBIRCH, PLUM ORCHARD)           604
# (MACARTHUR, OBERLIN)                 592
# (UNIVERSITY, OXFORD)                 570
# (SELFRIDGE, GRIDLEY)                 492
# (ARCOLA, GALT)                       420
# (PARKLAND, FAROE)                    410
# (POSTOAK, ENID)                      398
# (BEL PRE, ARCTIC)                    379
# (DIAMONDBACK, DECOVERLY)             374
# (HALPINE, CHAPMAN)                   291
# (GRANDVIEW, BLUERIDGE)               276
# (NORFOLK, FAIRMONT)                  240
# (GRANDVIEW, ENNALLS)                 231
# (OXFORD, UNIVERSITY)                 226
# (BROADBIRCH, BOURNEFIELD)            221
# (ENNALLS, GRANDVIEW)                 214
# (SHADY GROVE, PINEY MEETINGHOUSE)    212
# (GOOD HOPE, WINDMILL)                202
# (SLIGO CREEK, SCHUYLER)              193
# (MATENY, DAIRYMAID)                  190
# (AMHERST, REEDIE)                    185
# (SHAW, FALMOUTH)                     181
# (LELAND, GLENDALE)                   180
# (CRYSTAL ROCK, WATERS LANDING)       177
# (SCENERY, MIDDLEBROOK)               175
# (ARLISS, FLOWER)                     161
# (CHESHIRE, GROSVENOR)                157
# (NEBEL, MARINELLI)                   156
# (WATKINS MILL, TRAVIS)               155
#                                     ...
# (NEWPORT MILL, STARK)                117
# (GLENDALE, LELAND)                   113
# (PLYERS MILL, METROPOLITAN)          111
# (FALLSGROVE, BLACKWELL)              111
# (BROOKVILLE, WOODBINE)               108
# (KENTLANDS, BOOTH)                   107
# (BOILING BROOK, ROCKING HORSE)       105
# (ARCTIC, BAUER)                      105
# (RANDOLPH, COLIE)                    104
# (KENSINGTON, KENT)                   102
# (LINDEN, BEECH)                      101
# (AMHERST, PRICHARD)                  100
# (SAYBROOKE OAKS, VICTORY FARM)       100
# (CHAPMAN, HALPINE)                    99
# (GALWAY, KILKENNY)                    98
# (BELLS MILL, DEBORAH)                 97
# (CLARKSBURG, GATEWAY CENTER)          97
# (SNOWDEN FARM, NEWCUT)                97
# (STRINGTOWN, SNOWDEN FARM)            95
# (CRYSTAL ROCK, )                      93
# (WISTERIA, WARING STATION)            92
# (LONE OAK, ASHBURTON LA)              91
# (GOOD HOPE, WINDMILL LA)              87
# (LOCBURY, TOWN COMMONS)               86
# (SUFFIELD, BICKERSTAFF)               86
# (CEDAR TREE, MCKNEW)                  86
# (2ND, BALLARD)                        86
# (LANARK, LORAIN)                      84
# (, TRAVIS)                            84
# (SHAKESPEARE, NEELSVILLE CHURCH)      83
# Length: 74, dtype: int64
# 9280

# %% [markdown]
# # rollout plan

# %% [markdown]
# # Evaluation Plan

# %%
#pair wise t test
