# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.DataFrame(pd.read_csv("world.csv"))
df.head()
# Out:
#           Country                Region  Population  Area(sq.mi.)  \
# 0     Afghanistan  ASIA (EX. NEAR EAST)    31056997        647500
# 1         Albania        EASTERN EUROPE     3581655         28748
# 2         Algeria       NORTHERN AFRICA    32930091       2381740
# 3  American Samoa               OCEANIA       57794           199
# 4         Andorra        WESTERN EUROPE       71201           468
#
#   Pop.Density(persq.mi.) Coastline(coast/arearatio) Netmigration  \
# 0                   48,0                       0,00        23,06
# 1                  124,6                       1,26        -4,93
# 2                   13,8                       0,04        -0,39
# 3                  290,4                      58,29       -20,71
# 4                  152,1                       0,00          6,6
#
#   Infantmortality(per1000births)  GDP($percapita) Literacy(%) Phones(per1000)  \
# 0                         163,07            700.0        36,0             3,2
# 1                          21,52           4500.0        86,5            71,2
# 2                             31           6000.0        70,0            78,1
# 3                           9,27           8000.0        97,0           259,5
# 4                           4,05          19000.0       100,0           497,2
#
#   Arable(%) Crops(%) Other(%) Climate Birthrate Deathrate Agriculture  \
# 0     12,13     0,22    87,65       1      46,6     20,34        0,38
# 1     21,09     4,42    74,49       3     15,11      5,22       0,232
# 2      3,22     0,25    96,53       1     17,14      4,61       0,101
# 3        10       15       75       2     22,46      3,27         NaN
# 4      2,22        0    97,78       3      8,71      6,25         NaN
#
#   Industry Service
# 0     0,24    0,38
# 1    0,188   0,579
# 2      0,6   0,298
# 3      NaN     NaN
# 4      NaN     NaN

# %%
df1 = df.dropna()
df2 = df1.iloc[:,2:]
df2.head(5)
# Out:
#    Population  Area(sq.mi.) Pop.Density(persq.mi.) Coastline(coast/arearatio)  \
# 0    31056997        647500                   48,0                       0,00
# 1     3581655         28748                  124,6                       1,26
# 2    32930091       2381740                   13,8                       0,04
# 6       13477           102                  132,1                      59,80
# 7       69108           443                  156,0                      34,54
#
#   Netmigration Infantmortality(per1000births)  GDP($percapita) Literacy(%)  \
# 0        23,06                         163,07            700.0        36,0
# 1        -4,93                          21,52           4500.0        86,5
# 2        -0,39                             31           6000.0        70,0
# 6        10,76                          21,03           8600.0        95,0
# 7        -6,15                          19,46          11000.0        89,0
#
#   Phones(per1000) Arable(%) Crops(%) Other(%) Climate Birthrate Deathrate  \
# 0             3,2     12,13     0,22    87,65       1      46,6     20,34
# 1            71,2     21,09     4,42    74,49       3     15,11      5,22
# 2            78,1      3,22     0,25    96,53       1     17,14      4,61
# 6           460,0         0        0      100       2     14,17      5,34
# 7           549,9     18,18     4,55    77,27       2     16,93      5,37
#
#   Agriculture Industry Service
# 0        0,38     0,24    0,38
# 1       0,232    0,188   0,579
# 2       0,101      0,6   0,298
# 6        0,04     0,18    0,78
# 7       0,038     0,22   0,743

# %%
df3 = df2.iloc[:, 2:]
df3.drop(["GDP($percapita)"], axis = 1)
df3.head()
# Out:
#   Pop.Density(persq.mi.) Coastline(coast/arearatio) Netmigration  \
# 0                   48,0                       0,00        23,06
# 1                  124,6                       1,26        -4,93
# 2                   13,8                       0,04        -0,39
# 6                  132,1                      59,80        10,76
# 7                  156,0                      34,54        -6,15
#
#   Infantmortality(per1000births)  GDP($percapita) Literacy(%) Phones(per1000)  \
# 0                         163,07            700.0        36,0             3,2
# 1                          21,52           4500.0        86,5            71,2
# 2                             31           6000.0        70,0            78,1
# 6                          21,03           8600.0        95,0           460,0
# 7                          19,46          11000.0        89,0           549,9
#
#   Arable(%) Crops(%) Other(%) Climate Birthrate Deathrate Agriculture  \
# 0     12,13     0,22    87,65       1      46,6     20,34        0,38
# 1     21,09     4,42    74,49       3     15,11      5,22       0,232
# 2      3,22     0,25    96,53       1     17,14      4,61       0,101
# 6         0        0      100       2     14,17      5,34        0,04
# 7     18,18     4,55    77,27       2     16,93      5,37       0,038
#
#   Industry Service
# 0     0,24    0,38
# 1    0,188   0,579
# 2      0,6   0,298
# 6     0,18    0,78
# 7     0,22   0,743

# %%
def clean_col(c):
    new_col = []
    for r in c:
        if r.isdigit():
            new_col.append(float(r))
        else:
            vals = r.split(",")
            if vals[0].isdigit() and vals[1].isdigit():
                num = float(vals[0]) + (float(vals[1]) * (.1 ** len(vals[1])))
                new_col.append(num)
            elif vals[0][0] == "-" and vals[1].isdigit():
                num = (-1 * float(vals[0][1:])) - (float(vals[1]) * (.1 ** len(vals[1])))
                new_col.append(num)
            else:
                new_col.append(None)
    return new_col


def new_num(r):
     if r.isdigit():
        return float(r)
     else:
        vals = r.split(",")
        if vals[0].isdigit() and vals[1].isdigit():
            num = float(vals[0]) + (float(vals[1]) * (.1 ** len(vals[1])))
            return (num)
        elif vals[0][0] == "-" and vals[1].isdigit():
            num = (-1 * float(vals[0][1:])) - (float(vals[1]) * (.1 ** len(vals[1])))
            return (num)
        else:
            return (None)

for i, row in df3.iterrows():
    for j, column in row.iteritems():
        if not isinstance(column, float):
            df3.set_value(i, j, float(new_num(column)))


df3["Population"] = df2["Population"]
df3["Area(sq.mi.)"] = df2["Area(sq.mi.)"]
df3["GDP($percapita)"] = df2["GDP($percapita)"]

df3.head()
#print(clean_col(df2["Agriculture"]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:36: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   Pop.Density(persq.mi.) Coastline(coast/arearatio) Netmigration  \
# 0                     48                          0        23.06
# 1                  124.6                       1.26        -4.93
# 2                   13.8                       0.04        -0.39
# 6                  132.1                       59.8        10.76
# 7                    156                      34.54        -6.15
#
#   Infantmortality(per1000births)  GDP($percapita) Literacy(%) Phones(per1000)  \
# 0                         163.07            700.0          36             3.2
# 1                          21.52           4500.0        86.5            71.2
# 2                             31           6000.0          70            78.1
# 6                          21.03           8600.0          95             460
# 7                          19.46          11000.0          89           549.9
#
#   Arable(%) Crops(%) Other(%) Climate Birthrate Deathrate Agriculture  \
# 0     12.13     0.22    87.65       1      46.6     20.34        0.38
# 1     21.09     4.42    74.49       3     15.11      5.22       0.232
# 2      3.22     0.25    96.53       1     17.14      4.61       0.101
# 6         0        0      100       2     14.17      5.34        0.04
# 7     18.18     4.55    77.27       2     16.93      5.37       0.038
#
#   Industry Service  Population  Area(sq.mi.)
# 0     0.24    0.38    31056997        647500
# 1    0.188   0.579     3581655         28748
# 2      0.6   0.298    32930091       2381740
# 6     0.18    0.78       13477           102
# 7     0.22   0.743       69108           443

# %%
df3.to_csv("clean_world.csv")

# %%
df4 = pd.DataFrame(pd.read_csv("clean_world.csv"))
df4.head()
# Out:
#    Unnamed: 0  Pop.Density(persq.mi.)  Coastline(coast/arearatio)  \
# 0           0                    48.0                        0.00
# 1           1                   124.6                        1.26
# 2           2                    13.8                        0.04
# 3           6                   132.1                       59.80
# 4           7                   156.0                       34.54
#
#    Netmigration  Infantmortality(per1000births)  GDP($percapita)  Literacy(%)  \
# 0         23.06                          163.07            700.0         36.0
# 1         -4.93                           21.52           4500.0         86.5
# 2         -0.39                           31.00           6000.0         70.0
# 3         10.76                           21.03           8600.0         95.0
# 4         -6.15                           19.46          11000.0         89.0
#
#    Phones(per1000)  Arable(%)  Crops(%)  Other(%)  Climate  Birthrate  \
# 0              3.2      12.13      0.22     87.65      1.0      46.60
# 1             71.2      21.09      4.42     74.49      3.0      15.11
# 2             78.1       3.22      0.25     96.53      1.0      17.14
# 3            460.0       0.00      0.00    100.00      2.0      14.17
# 4            549.9      18.18      4.55     77.27      2.0      16.93
#
#    Deathrate  Agriculture  Industry  Service  Population  Area(sq.mi.)
# 0      20.34        0.380     0.240    0.380    31056997        647500
# 1       5.22        0.232     0.188    0.579     3581655         28748
# 2       4.61        0.101     0.600    0.298    32930091       2381740
# 3       5.34        0.040     0.180    0.780       13477           102
# 4       5.37        0.038     0.220    0.743       69108           443

# %%
# Make the correlation matrix.
corrmat = df4.corr()
print(corrmat)

# Set up the matplotlib figure.
f, ax = plt.subplots(figsize=(20, 18))

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
# Heatmaps are a great way to get a quick visual read on a big correlation matrix.

# Try to match the correlation numbers to the scatterplots above to get a 
# sense of what each magnitude of correlation can look like.
# Out:
#                                 Unnamed: 0  Pop.Density(persq.mi.)  \
# Unnamed: 0                        1.000000                0.020027
# Pop.Density(persq.mi.)            0.020027                1.000000
# Coastline(coast/arearatio)        0.020880                0.164036
# Netmigration                     -0.066842                0.161705
# Infantmortality(per1000births)   -0.022118               -0.143214
# GDP($percapita)                  -0.030122                0.190122
# Literacy(%)                       0.038638                0.086090
# Phones(per1000)                  -0.047964                0.157072
# Arable(%)                        -0.010080               -0.059223
# Crops(%)                          0.138906               -0.036580
# Other(%)                         -0.061578                0.066753
# Climate                          -0.048224               -0.012370
# Birthrate                         0.034633               -0.174565
# Deathrate                         0.006486               -0.130624
# Agriculture                      -0.003993               -0.144315
# Industry                          0.095485               -0.145370
# Service                          -0.072057                0.255477
# Population                       -0.042891               -0.019010
# Area(sq.mi.)                     -0.062523               -0.069010
#
#                                 Coastline(coast/arearatio)  Netmigration  \
# Unnamed: 0                                        0.020880     -0.066842
# Pop.Density(persq.mi.)                            0.164036      0.161705
# Coastline(coast/arearatio)                        1.000000     -0.241629
# Netmigration                                     -0.241629      1.000000
# Infantmortality(per1000births)                   -0.105956      0.013053
# GDP($percapita)                                   0.035815      0.378790
# Literacy(%)                                       0.099605     -0.053788
# Phones(per1000)                                   0.098367      0.232446
# Arable(%)                                        -0.077800     -0.065846
# Crops(%)                                          0.399358     -0.405355
# Other(%)                                         -0.137085      0.257420
# Climate                                          -0.027063     -0.070413
# Birthrate                                        -0.063464     -0.035102
# Deathrate                                        -0.148592      0.042805
# Agriculture                                      -0.032327     -0.096617
# Industry                                         -0.188972     -0.004402
# Service                                           0.190004      0.091498
# Population                                       -0.054617      0.010332
# Area(sq.mi.)                                     -0.088162      0.052730
#
#                                 Infantmortality(per1000births)  \
# Unnamed: 0                                           -0.022118
# Pop.Density(persq.mi.)                               -0.143214
# Coastline(coast/arearatio)                           -0.105956
# Netmigration                                          0.013053
# Infantmortality(per1000births)                        1.000000
# GDP($percapita)                                      -0.639090
# Literacy(%)                                          -0.761224
# Phones(per1000)                                      -0.699199
# Arable(%)                                            -0.123033
# Crops(%)                                             -0.095712
# Other(%)                                              0.148600
# Climate                                              -0.366672
# Birthrate                                             0.862113
# Deathrate                                             0.665729
# Agriculture                                           0.758537
# Industry                                             -0.085310
# Service                                              -0.618259
# Population                                            0.002438
# Area(sq.mi.)                                          0.002924
#
#                                 GDP($percapita)  Literacy(%)  Phones(per1000)  \
# Unnamed: 0                            -0.030122     0.038638        -0.047964
# Pop.Density(persq.mi.)                 0.190122     0.086090         0.157072
# Coastline(coast/arearatio)             0.035815     0.099605         0.098367
# Netmigration                           0.378790    -0.053788         0.232446
# Infantmortality(per1000births)        -0.639090    -0.761224        -0.699199
# GDP($percapita)                        1.000000     0.522880         0.883520
# Literacy(%)                            0.522880     1.000000         0.592042
# Phones(per1000)                        0.883520     0.592042         1.000000
# Arable(%)                              0.046465     0.086519         0.124116
# Crops(%)                              -0.207844     0.060741        -0.124819
# Other(%)                               0.066445    -0.101167        -0.038643
# Climate                                0.360567     0.395194         0.410691
# Birthrate                             -0.658795    -0.788349        -0.732985
# Deathrate                             -0.247562    -0.401696        -0.317530
# Agriculture                           -0.616919    -0.620514        -0.631578
# Industry                               0.032855     0.105703        -0.084247
# Service                                0.536551     0.474395         0.649638
# Population                            -0.033618    -0.038162        -0.003942
# Area(sq.mi.)                           0.068356     0.000682         0.077864
#
#                                 Arable(%)  Crops(%)  Other(%)   Climate  \
# Unnamed: 0                      -0.010080  0.138906 -0.061578 -0.048224
# Pop.Density(persq.mi.)          -0.059223 -0.036580  0.066753 -0.012370
# Coastline(coast/arearatio)      -0.077800  0.399358 -0.137085 -0.027063
# Netmigration                    -0.065846 -0.405355  0.257420 -0.070413
# Infantmortality(per1000births)  -0.123033 -0.095712  0.148600 -0.366672
# GDP($percapita)                  0.046465 -0.207844  0.066445  0.360567
# Literacy(%)                      0.086519  0.060741 -0.101167  0.395194
# Phones(per1000)                  0.124116 -0.124819 -0.038643  0.410691
# Arable(%)                        1.000000  0.098265 -0.866058  0.392914
# Crops(%)                         0.098265  1.000000 -0.582627 -0.003734
# Other(%)                        -0.866058 -0.582627  1.000000 -0.318964
# Climate                          0.392914 -0.003734 -0.318964  1.000000
# Birthrate                       -0.198438  0.075813  0.123943 -0.456312
# Deathrate                        0.047770 -0.208984  0.066027  0.021979
# Agriculture                     -0.018610  0.084289 -0.027108 -0.187472
# Industry                        -0.073380 -0.124211  0.122303 -0.077286
# Service                          0.081982  0.029020 -0.081546  0.237414
# Population                       0.206667 -0.062567 -0.137345 -0.018471
# Area(sq.mi.)                    -0.053747 -0.160433  0.124528 -0.094852
#
#                                 Birthrate  Deathrate  Agriculture  Industry  \
# Unnamed: 0                       0.034633   0.006486    -0.003993  0.095485
# Pop.Density(persq.mi.)          -0.174565  -0.130624    -0.144315 -0.145370
# Coastline(coast/arearatio)      -0.063464  -0.148592    -0.032327 -0.188972
# Netmigration                    -0.035102   0.042805    -0.096617 -0.004402
# Infantmortality(per1000births)   0.862113   0.665729     0.758537 -0.085310
# GDP($percapita)                 -0.658795  -0.247562    -0.616919  0.032855
# Literacy(%)                     -0.788349  -0.401696    -0.620514  0.105703
# Phones(per1000)                 -0.732985  -0.317530    -0.631578 -0.084247
# Arable(%)                       -0.198438   0.047770    -0.018610 -0.073380
# Crops(%)                         0.075813  -0.208984     0.084289 -0.124211
# Other(%)                         0.123943   0.066027    -0.027108  0.122303
# Climate                         -0.456312   0.021979    -0.187472 -0.077286
# Birthrate                        1.000000   0.446220     0.703979 -0.120518
# Deathrate                        0.446220   1.000000     0.416409 -0.012611
# Agriculture                      0.703979   0.416409     1.000000 -0.352785
# Industry                        -0.120518  -0.012611    -0.352785  1.000000
# Service                         -0.541710  -0.366187    -0.613489 -0.521413
# Population                      -0.064719  -0.050578    -0.007401  0.092468
# Area(sq.mi.)                    -0.037473  -0.024266    -0.017035  0.103225
#
#                                  Service  Population  Area(sq.mi.)
# Unnamed: 0                     -0.072057   -0.042891     -0.062523
# Pop.Density(persq.mi.)          0.255477   -0.019010     -0.069010
# Coastline(coast/arearatio)      0.190004   -0.054617     -0.088162
# Netmigration                    0.091498    0.010332      0.052730
# Infantmortality(per1000births) -0.618259    0.002438      0.002924
# GDP($percapita)                 0.536551   -0.033618      0.068356
# Literacy(%)                     0.474395   -0.038162      0.000682
# Phones(per1000)                 0.649638   -0.003942      0.077864
# Arable(%)                       0.081982    0.206667     -0.053747
# Crops(%)                        0.029020   -0.062567     -0.160433
# Other(%)                       -0.081546   -0.137345      0.124528
# Climate                         0.237414   -0.018471     -0.094852
# Birthrate                      -0.541710   -0.064719     -0.037473
# Deathrate                      -0.366187   -0.050578     -0.024266
# Agriculture                    -0.613489   -0.007401     -0.017035
# Industry                       -0.521413    0.092468      0.103225
# Service                         1.000000   -0.070320     -0.070204
# Population                     -0.070320    1.000000      0.610850
# Area(sq.mi.)                   -0.070204    0.610850      1.000000

# %%
# create 10 features and explain
df4["Country"] = df.dropna()["Country"]
df4["Region"] = df.dropna()["Region"]

features = pd.get_dummies(df4["Country"])

features["Smart"] = np.where((df4["Literacy(%)"] * df4["Phones(per1000)"] > 500), 1, 0)

features["Growing"] = (df4["Birthrate"] - df4["Deathrate"])

features["Welcoming"] = np.where(df4["Netmigration"]>0, 1, 0)

features["Crammed"] = np.where(df4["Pop.Density(persq.mi.)"] > 100, 1, 0)

#features[""]

# %%
#pca
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 

X = StandardScaler().fit_transform(df4)

sklearn_pca = PCA(n_components=5)
Y_sklearn = sklearn_pca.fit_transform(X)

print(
    'The percentage of total variance in the dataset explained by each',
    'component from Sklearn PCA.\n',
    sklearn_pca.explained_variance_ratio_
)
# Out:
# The percentage of total variance in the dataset explained by each component from Sklearn PCA.
#  [0.29249881 0.13498684 0.10010554 0.08678803 0.07701554]
